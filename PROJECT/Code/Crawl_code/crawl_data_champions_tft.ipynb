# %% [markdown]
# ### Crawl a page with requests and parse it with Beautiful Soup
# https://nathanaelvictorious.medium.com/simple-web-scraping-using-beautifulsoup-and-python-in-google-colab-4084be701851

# %% [markdown]
# Overview

# %%
# Import requests for crawling a page and Beautiful Soup for parse the HTML content
# Import other libraries for demonstration
from bs4 import BeautifulSoup
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Fetch a website URL and store it to webpage
overview_webpage_a = requests.get("https://blitz.gg/tft/champions/overview?set=8&sortBy=name&sortDirection=ASC")
overview_webpage_z = requests.get("https://blitz.gg/tft/champions/overview?set=8&sortBy=name&sortDirection=DESC")
#Take the webpage variable and fetch the content using BeautifulSoup
soup_overview_a = BeautifulSoup(overview_webpage_a.content, "html.parser")
soup_overview_z = BeautifulSoup(overview_webpage_z.content, "html.parser")

# %%
# Store the whole text in HTML that have the class "Rating" and "CocoaPercent"
name_champions_a = soup_overview_a.find_all(attrs={"class": "type-body2"})   # 0 la ten, 1 la gia, 8 la tam danh
traits_a = soup_overview_a.find_all(attrs={"class": "⚡a40f4298 ⚡904d395"}) # moi phan tu se chua toc he trong name cua 1 vi tuong theo thu tu 1, 3, 5, ...

# Store the whole text in HTML that have the class "Rating" and "CocoaPercent"
name_champions_z = soup_overview_z.find_all(attrs={"class": "type-body2"})   # 0 la ten, 1 la gia, 8 la tam danh
traits_z = soup_overview_z.find_all(attrs={"class": "⚡a40f4298 ⚡904d395"}) # moi phan tu se chua toc he trong name cua 1 vi tuong theo thu tu 1, 3, 5, ...

# Them gia tri bi khuyet trong web
name_champions_z.insert(248, 0)
name_champions_z.insert(249, 0)

# %%
# print(len(name_champions_a))
# for i in range(0, len(name_champions_a), 9):
#     print(name_champions_a[i].text)

# for i in range(0, len(name_champions_z), 9):
#     print(name_champions_z[i].text)
trait_champions = []
list_name_champions = []

for i in range(1, len(traits_a), 2):
    pos = int(((i-1)/2)*9)
    if(list_name_champions.count(name_champions_a[pos].text) == 0):
        trait_champions.append([])
        list_name_champions.append(name_champions_a[pos].text)
        temp1 = []
        for j in traits_a[i].find_all('div', class_ = "⚡afdc06"):
            temp = (j['name'])
            temp1.append(temp)
        trait_champions[-1].append(temp1)  

for i in range(1, len(traits_z), 2):
    pos = int(((i-1)/2)*9)
    if(list_name_champions.count(name_champions_z[pos].text) == 0):
        trait_champions.append([])
        list_name_champions.append(name_champions_z[pos].text)
        temp1 = []
        for j in traits_z[i].find_all('div', class_ = "⚡afdc06"):
            temp = (j['name'])
            temp1.append(temp)
        trait_champions[-1].append(temp1)

# %%
data_champions_tft_df = pd.DataFrame(data = trait_champions,index = list_name_champions, columns=['Traits']).sort_index()
data_champions_tft_df
# Out:
#                                             Traits
# Alistar                   [aegis, mascot, oxforce]
# Annie           [spellslinger, gadgeteen, oxforce]
# Aphelios              [sureshot, arsenal, oxforce]
# Ashe                           [recon, lasercorps]
# Aurelion Sol                              [threat]
# Bel'Veth                                  [threat]
# Blitzcrank                        [brawler, admin]
# Camille                          [renegade, admin]
# Cho'Gath                                  [threat]
# Draven                           [ace, mechaprime]
# Ekko              [aegis, prankster, starguardian]
# Ezreal                        [recon, underground]
# Fiddlesticks                   [corrupted, threat]
# Fiora                           [duelist, oxforce]
# Galio                           [mascot, civilian]
# Gangplank                        [duelist, supers]
# Janna                       [forecaster, civilian]
# Jax                          [brawler, mechaprime]
# Jinx                       [prankster, animasquad]
# Kai'Sa                       [recon, starguardian]
# Kayle                       [duelist, underground]
# LeBlanc              [hacker, spellslinger, admin]
# Lee Sin                   [brawler, heart, supers]
# Leona                [aegis, renegade, mechaprime]
# Lux                   [spellslinger, starguardian]
# Malphite                          [mascot, supers]
# Miss Fortune                     [ace, animasquad]
# Mordekaiser                      [ace, lasercorps]
# Nasus                         [mascot, animasquad]
# Nilah                      [duelist, starguardian]
# Nunu & Willump                 [mascot, gadgeteen]
# Poppy                        [defender, gadgeteen]
# Rammus                                    [threat]
# Rell                      [defender, starguardian]
# Renekton                     [brawler, lasercorps]
# Riven              [brawler, defender, animasquad]
# Samira                [ace, sureshot, underground]
# Sejuani                      [brawler, lasercorps]
# Senna                       [sureshot, lasercorps]
# Sett                        [defender, mechaprime]
# Sivir                         [sureshot, civilian]
# Sona            [heart, spellslinger, underground]
# Soraka                              [heart, admin]
# Sylas                       [renegade, animasquad]
# Syndra                       [heart, starguardian]
# Taliyah               [spellslinger, starguardian]
# Talon                          [renegade, oxforce]
# Urgot                                     [threat]
# Vayne                 [duelist, recon, animasquad]
# Vel'Koz                                   [threat]
# Vi                   [aegis, brawler, underground]
# Viego                          [renegade, oxforce]
# Wukong                      [defender, mechaprime]
# Yasuo                        [duelist, lasercorps]
# Yuumi                [heart, mascot, starguardian]
# Zac                                       [threat]
# Zed                  [duelist, hacker, lasercorps]
# Zoe                 [hacker, prankster, gadgeteen]

# %% [markdown]
# Stat

# %%
# Fetch a website URL and store it to webpage
stat_webpage_a = requests.get("https://blitz.gg/tft/champions/stats?set=8&sortBy=champion&sortDirection=DESC")
stat_webpage_z = requests.get("https://blitz.gg/tft/champions/stats?set=8&sortBy=champion&sortDirection=ASC")

#Take the webpage variable and fetch the content using BeautifulSoup
soup_stat_a = BeautifulSoup(stat_webpage_a.content, "html.parser")
soup_stat_z = BeautifulSoup(stat_webpage_z.content, "html.parser")

# %%
# Store the whole text in HTML
champion_stat_a = soup_stat_z.find_all(attrs={"class": "type-body2"})    # 0: ten tuong, 1: vi tri TB, 2: top4, 3: ti le win, 4: tong so tran
champion_stat_z = soup_stat_a.find_all(attrs={"class": "type-body2"})    # 0: ten tuong, 1: vi tri TB, 2: top4, 3: ti le win, 4: tong so tran

# %%
champion_stat_a[0].text
champion_stat_a[1].text
champion_stat_a[2].text
# Out:
# '45.2%'

# %%
stat_champions_df = pd.DataFrame(index=list_name_champions, columns=['Avg Place', 'Top 4', 'Top 1'])

for i in range(0, len(champion_stat_a), 5):
    name = champion_stat_a[i].text
    stat_champions_df.loc[name]['Avg Place'] = float(champion_stat_a[i+1].text)
    stat_champions_df.loc[name]['Top 4'] = str(champion_stat_a[i+2].text)
    stat_champions_df.loc[name]['Top 1'] = str(champion_stat_a[i+3].text)

for i in range(0, len(champion_stat_z), 5):
    name = champion_stat_z[i].text
    stat_champions_df.loc[name]['Avg Place'] = float(champion_stat_z[i+1].text)
    stat_champions_df.loc[name]['Top 4'] = str(champion_stat_z[i+2].text)
    stat_champions_df.loc[name]['Top 1'] = str(champion_stat_z[i+3].text)

# %%
data_champions_tft_df = data_champions_tft_df.assign(Avg_Place = stat_champions_df['Avg Place'], Top_4 = stat_champions_df['Top 4'], Top_1 = stat_champions_df['Top 1'])

# %%
data_champions_tft_df.to_csv('data_champion_tft.csv')

# %%
data_champions_tft_df.sort_values('Avg_Place')
# Out:
#                                             Traits Avg_Place  Top_4  Top_1
# Annie           [spellslinger, gadgeteen, oxforce]       4.1  56.8%  17.2%
# Vel'Koz                                   [threat]       4.1  56.7%  16.6%
# Talon                          [renegade, oxforce]       4.1  56.3%  19.0%
# Sett                        [defender, mechaprime]       4.1  56.6%  15.4%
# Nasus                         [mascot, animasquad]       4.1  56.1%  17.7%
# Malphite                          [mascot, supers]       4.1  56.7%  16.6%
# Jinx                       [prankster, animasquad]       4.1  56.6%  17.6%
# Gangplank                        [duelist, supers]       4.1  57.2%  16.1%
# Lux                   [spellslinger, starguardian]       4.1  56.7%  16.9%
# Galio                           [mascot, civilian]       4.1  57.0%  17.2%
# Yuumi                [heart, mascot, starguardian]       4.2  55.8%  16.3%
# Fiora                           [duelist, oxforce]       4.2  55.7%  14.2%
# Kai'Sa                       [recon, starguardian]       4.2  55.7%  14.6%
# Lee Sin                   [brawler, heart, supers]       4.2  56.2%  16.4%
# Camille                          [renegade, admin]       4.2  54.0%  17.3%
# Cho'Gath                                  [threat]       4.2  55.4%  15.6%
# Samira                [ace, sureshot, underground]       4.2  54.7%  16.7%
# Rammus                                    [threat]       4.2  55.3%  15.4%
# Riven              [brawler, defender, animasquad]       4.2  55.6%  15.8%
# Vi                   [aegis, brawler, underground]       4.3  53.4%  16.0%
# Sylas                       [renegade, animasquad]       4.3  52.3%  16.3%
# Rell                      [defender, starguardian]       4.3  53.3%  14.0%
# Blitzcrank                        [brawler, admin]       4.4  51.4%  14.6%
# Jax                          [brawler, mechaprime]       4.4  52.3%  14.0%
# Draven                           [ace, mechaprime]       4.5  50.6%  13.7%
# Sona            [heart, spellslinger, underground]       4.5  50.1%  14.6%
# Wukong                      [defender, mechaprime]       4.5  50.8%  13.8%
# Ezreal                        [recon, underground]       4.6  47.3%  12.5%
# Kayle                       [duelist, underground]       4.7  45.3%  10.4%
# Poppy                        [defender, gadgeteen]       4.8  45.2%   9.3%
# Alistar                   [aegis, mascot, oxforce]       NaN    NaN    NaN
# Aphelios              [sureshot, arsenal, oxforce]       NaN    NaN    NaN
# Ashe                           [recon, lasercorps]       NaN    NaN    NaN
# Aurelion Sol                              [threat]       NaN    NaN    NaN
# Bel'Veth                                  [threat]       NaN    NaN    NaN
# Ekko              [aegis, prankster, starguardian]       NaN    NaN    NaN
# Fiddlesticks                   [corrupted, threat]       NaN    NaN    NaN
# Janna                       [forecaster, civilian]       NaN    NaN    NaN
# LeBlanc              [hacker, spellslinger, admin]       NaN    NaN    NaN
# Leona                [aegis, renegade, mechaprime]       NaN    NaN    NaN
# Miss Fortune                     [ace, animasquad]       NaN    NaN    NaN
# Mordekaiser                      [ace, lasercorps]       NaN    NaN    NaN
# Nilah                      [duelist, starguardian]       NaN    NaN    NaN
# Nunu & Willump                 [mascot, gadgeteen]       NaN    NaN    NaN
# Renekton                     [brawler, lasercorps]       NaN    NaN    NaN
# Sejuani                      [brawler, lasercorps]       NaN    NaN    NaN
# Senna                       [sureshot, lasercorps]       NaN    NaN    NaN
# Sivir                         [sureshot, civilian]       NaN    NaN    NaN
# Soraka                              [heart, admin]       NaN    NaN    NaN
# Syndra                       [heart, starguardian]       NaN    NaN    NaN
# Taliyah               [spellslinger, starguardian]       NaN    NaN    NaN
# Urgot                                     [threat]       NaN    NaN    NaN
# Vayne                 [duelist, recon, animasquad]       NaN    NaN    NaN
# Viego                          [renegade, oxforce]       NaN    NaN    NaN
# Yasuo                        [duelist, lasercorps]       NaN    NaN    NaN
# Zac                                       [threat]       NaN    NaN    NaN
# Zed                  [duelist, hacker, lasercorps]       NaN    NaN    NaN
# Zoe                 [hacker, prankster, gadgeteen]       NaN    NaN    NaN
